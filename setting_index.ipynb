# %%
import pandas as pd

# %%
df = pd.read_csv('../data/stackoverflow_dev_survey/survey_results_schema.csv')
# df = pd.read_csv('../data/stackoverflow_dev_survey/survey_results_schema.csv', index_col='qid')
df.head(5)
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
# The index that you set must be unique.

df.set_index('qid', inplace=True)

# %%
df.head(5)
# Out:
#            qname                                           question  \
# qid
# QID16         S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12   MetaInfo                                  Browser Meta Info
# QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# QID312      Q120
# QID1          S1  <span style="font-size:22px; font-family: aria...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# QID312       True    MC     SAVR
# QID1        False    DB       TB

# %%
df.loc['QID12']
# Out:
# qname                  MetaInfo
# question      Browser Meta Info
# force_resp                False
# type                       Meta
# selector                Browser
# Name: QID12, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
# Sorting indexes:

df.sort_index(ascending=True, inplace=True)
df
# Out:
#               qname                                           question  \
# qid
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID106       SOComm  Do you consider yourself a member of the Stack...
# ...             ...                                                ...
# QID51     CompTotal  What is your current total <b>annual</b> compe...
# QID6        Country  Where do you live? <span style="font-weight: b...
# QID61            S3  <span style="font-size:22px; font-family: aria...
# QID71         OpSys  What is the primary <b>operating system</b> in...
# QID91            S4  <span style="font-size:22px; font-family: aria...
#
#        force_resp    type selector
# qid
# QID1        False      DB       TB
# ...
